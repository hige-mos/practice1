# %%
import pandas as pd
import numpy as np
import json

# %%
# !python report_json.py
# Out:
# MiET
# 1
# N2OB
# 1
# Finish!

# %%
with open('./jsonFiles/allconfig.json', encoding='utf-8') as f:
    allconfig = json.load(f)

### initialization part ###
Controllist = allconfig['control']
ss= allconfig['scenario']
dropnum = allconfig['drop_num']
ssinfo = allconfig['scenario_info']

# %%
def dict_to_dframe(datadict):
    var_df = pd.DataFrame()
    for s,S in datadict.items():
        for control,CONTROL in S.items():
            for drop,DROP in CONTROL.items():
                for node,NODE in DROP.items():
                    keys = []
                    vals = []
                    for k,v in NODE.items():#print(k,v)
                        keys.append(k)
                        vals.append(v)
                    tmp_se = pd.Series(vals, index = keys)
                    var_df = var_df.append(tmp_se,ignore_index=True)
    return var_df

# %%
def list_to_dict(df):
    c_dict = {}
    for i in range(len(df.index[0]) - 1, -1 ,-1):
        p_dict = {}
        for index1 in range(0,len(list(set(df.index.get_level_values(i))))):
            p_dict[list(set(df.index.get_level_values(i)))[index1]] = c_dict.copy()
        c_dict = p_dict.copy()
    
    for s,S in c_dict.items():
        for act,ACT in S.items():
            for r,R in ACT.items():
                    if (s,act,r) in df.index:
                        c_dict[s][act][r] = df.loc[s,act,r].to_dict()
                    else:
                        del c_dict[s][act][r]
    return (c_dict)

# %%
datadict = {}
for control in Controllist:
    with open('./jsonFiles/extract_json_'+ ss + '_'+ control + '.json', encoding='utf-8') as f:
        datadict.update(json.load(f))

# %%
def concat_max_min(node,df):
    Max_Min = pd.DataFrame({'Node': [node,node],
                            'Max_Min': ['Max','Min']})
    
    df = df[df['act'] == node] if node in ['AP','STA'] else df
    df = pd.concat([df.max(), df.min()] ,axis=1).T
    df = pd.concat([df,Max_Min] , axis=1)
    return df

# %%
dframe = dict_to_dframe(datadict).replace(np.nan,0).drop(['x', 'y','z','Uflow_num','Dflow_num','drop','bss','control','inter','role'], axis=1)

# %%
dframe[dframe['Dsinr']==50.4]
# Out:
#      Dmcs  Dsinr  Dthr  Dtraf  Umcs  Usinr  Uthr  Utraf  act assoc   ...    \
# 289   6.0   50.4   0.0    0.0   0.0    6.1   0.0    0.0  STA  [51]   ...
#
#      notdetect  reover  rxtime  rxtimeme  rxtimeo  rxtimes  sent   ss  txp  \
# 289        0.0     0.0     3.3       0.7      2.2      0.4   2.0  ss5  0.0
#
#      txtime
# 289     0.0
#
# [1 rows x 27 columns]

# %%
dframe_AP = concat_max_min('AP',dframe.copy())
dframe_STA = concat_max_min('STA',dframe.copy())
dframe_COMMON = concat_max_min('Common',dframe.copy())

# %%
dframe_AP
# Out:
#   Dmcs Dsinr   Dthr Dtraf Umcs Usinr   Uthr Utraf act                 assoc  \
# 0  6.7  29.9  111.4   250    7  28.7  132.8   200  AP  [448, 449, 450, 451]
# 1  2.7  10.9    0.1   150    2   5.4    1.2   100  AP      [92, 93, 94, 95]
#
#     ...   rxtime rxtimeme rxtimeo rxtimes    sent   ss   txp txtime Node  \
# 0   ...     12.5       12     2.2       0  190144  ss5  18.2    7.5   AP
# 1   ...      1.4      0.6       0       0     136  ss5  -1.9    0.1   AP
#
#   Max_Min
# 0     Max
# 1     Min
#
# [2 rows x 29 columns]

# %%
dframe_STA
# Out:
#   Dmcs Dsinr  Dthr Dtraf Umcs Usinr Uthr Utraf  act assoc   ...   rxtime  \
# 0    7  50.4  76.6   100    7  28.7  100   100  STA  [91]   ...     15.1
# 1    0   6.5     0     0    0   5.4    0     0  STA   [2]   ...      0.6
#
#   rxtimeme rxtimeo rxtimes    sent   ss   txp txtime Node Max_Min
# 0        7     2.2    14.8  170715  ss5    15   12.1  STA     Max
# 1      0.2       0       0       2  ss5 -13.6      0  STA     Min
#
# [2 rows x 29 columns]

# %%
dframe_COMMON
# Out:
#   Dmcs Dsinr   Dthr Dtraf Umcs Usinr   Uthr Utraf  act                 assoc  \
# 0    7  50.4  111.4   250    7  28.7  132.8   200  STA  [448, 449, 450, 451]
# 1    0   6.5      0     0    0   5.4      0     0   AP                   [2]
#
#     ...   rxtime rxtimeme rxtimeo rxtimes    sent   ss   txp txtime    Node  \
# 0   ...     15.1       12     2.2    14.8  190144  ss5  18.2   12.1  Common
# 1   ...      0.6      0.2       0       0       2  ss5 -13.6      0  Common
#
#   Max_Min
# 0     Max
# 1     Min
#
# [2 rows x 29 columns]

# %%
pd.concat([dframe_AP, dframe_STA.drop(columns=['Dsinr', 'Dthr']), dframe_COMMON.drop(columns=['Dsinr', 'Dthr'])],axis = 0,sort=True)
# Out:
#   Dmcs Dsinr   Dthr Dtraf Max_Min    Node Umcs Usinr   Uthr Utraf  ...    \
# 0  6.7  29.9  111.4   250     Max      AP    7  28.7  132.8   200  ...
# 1  2.7  10.9    0.1   150     Min      AP    2   5.4    1.2   100  ...
# 0    7   NaN    NaN   100     Max     STA    7  28.7    100   100  ...
# 1    0   NaN    NaN     0     Min     STA    0   5.4      0     0  ...
# 0    7   NaN    NaN   250     Max  Common    7  28.7  132.8   200  ...
# 1    0   NaN    NaN     0     Min  Common    0   5.4      0     0  ...
#
#   notdetect reover rxtime rxtimeme rxtimeo rxtimes    sent   ss   txp txtime
# 0         0  797.1   12.5       12     2.2       0  190144  ss5  18.2    7.5
# 1         0   24.2    1.4      0.6       0       0     136  ss5  -1.9    0.1
# 0        64    475   15.1        7     2.2    14.8  170715  ss5    15   12.1
# 1         0      0    0.6      0.2       0       0       2  ss5 -13.6      0
# 0        64  797.1   15.1       12     2.2    14.8  190144  ss5  18.2   12.1
# 1         0      0    0.6      0.2       0       0       2  ss5 -13.6      0
#
# [6 rows x 29 columns]

# %%
axisrange = pd.concat([dframe_AP, dframe_STA, dframe_COMMON],axis = 0,sort=True).set_index(['ss','Node','Max_Min'])
# Out:
#                    Dmcs Dsinr   Dthr Dtraf Umcs Usinr   Uthr Utraf  act  \
# ss  Node   Max_Min
# ss5 AP     Max      6.7  29.9  111.4   250    7  28.7  132.8   200   AP
#            Min      2.7  10.9    0.1   150    2   5.4    1.2   100   AP
#     STA    Max        7  50.4   76.6   100    7  28.7    100   100  STA
#            Min        0   6.5      0     0    0   5.4      0     0  STA
#     Common Max        7  50.4  111.4   250    7  28.7  132.8   200  STA
#            Min        0   6.5      0     0    0   5.4      0     0   AP
#
#                                    assoc  ...   node notdetect reover rxtime  \
# ss  Node   Max_Min                        ...
# ss5 AP     Max      [448, 449, 450, 451]  ...     91         0  797.1   12.5
#            Min          [92, 93, 94, 95]  ...      2         0   24.2    1.4
#     STA    Max                      [91]  ...    451        64    475   15.1
#            Min                       [2]  ...     92         0      0    0.6
#     Common Max      [448, 449, 450, 451]  ...    451        64  797.1   15.1
#            Min                       [2]  ...      2         0      0    0.6
#
#                    rxtimeme rxtimeo rxtimes    sent   txp txtime
# ss  Node   Max_Min
# ss5 AP     Max           12     2.2       0  190144  18.2    7.5
#            Min          0.6       0       0     136  -1.9    0.1
#     STA    Max            7     2.2    14.8  170715    15   12.1
#            Min          0.2       0       0       2 -13.6      0
#     Common Max           12     2.2    14.8  190144  18.2   12.1
#            Min          0.2       0       0       2 -13.6      0
#
# [6 rows x 26 columns]

# %%
path = './jsonFiles/axisrange.json'
with open(path,encoding='utf-8') as ex:
    axisrange_dict = json.load(ex)

axisrange_dict.update(list_to_dict(axisrange))

# %%
with open(path, 'w') as ex:
    ex.write(json.dumps(axisrange_dict,indent=4))
